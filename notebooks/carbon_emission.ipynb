# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('../dataset/Carbon_(CO2)_Emissions_by_Country.csv')

# %%
data.head()
# Out:
#        Country Region        Date  Kilotons of Co2  Metric Tons Per Capita
# 0  Afghanistan   Asia  01-01-2011           8930.0                    0.31
# 1  Afghanistan   Asia  01-01-2012           8080.0                    0.27
# 2  Afghanistan   Asia  01-01-2010           7110.0                    0.25
# 3  Afghanistan   Asia  01-01-2019           6080.0                    0.16
# 4  Afghanistan   Asia  01-01-2018           6070.0                    0.17

# %%
for i , j in friendships : 
    print(users[i])

# %%
data.describe()

# %%
mada = data[data["Country"] == "Madagascar"]

# %%
data[data["Country"].isin(["Madagascar","Afghanistan"])]

# %%
y = mada['Kilotons of Co2']
x = [i for i in range(len(y))]
plt.plot(x,y,c='r')

# %%
data.duplicated().sum()
data.isna().sum()

# %%
countries = pd.get_dummies(data["Country"])
countries = countries.astype(int)

date = pd.get_dummies(data["Date"])
date = date.astype(int)

region = pd.get_dummies(data['Region'])
region = region.astype(int)

# %%
data.drop(['Country','Date','Region'] , inplace = True , axis = 1)

# %%
data = data.join([countries,date,region])

# %%
data.head()

# %%
y = data['Kilotons of Co2']
x = data.drop(['Kilotons of Co2'] , axis = 1)

# %%
x.head()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , r2_score

# %%
model = LinearRegression()
x_train ,  x_test , y_train , y_test = train_test_split(x,y,train_size=0.3,random_state=42)
model.fit(x,y)
y_predicted = model.predict(x_test)
mse = mean_squared_error(y_test , y_predicted)
r2 = r2_score(y_test , y_predicted)
r2

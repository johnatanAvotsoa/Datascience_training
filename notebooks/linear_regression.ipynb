# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../dataset/headbrain.csv')
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
plt.scatter(X,Y)
plt.plot(X,Y_predicted , color='red')

# %%
# R squarred for model accuracy

num = np.sum((Y_predicted - y_mean) ** 2)
den = np.sum((Y - y_mean) ** 2) 
R_squared = num / den 
R_squared
# Out:
# 0.639311719957
